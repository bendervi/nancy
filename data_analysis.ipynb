# %% [markdown]
# # Data analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd

# %%
data = [
    ["2025-06-20","AVGO","stock","EXERCISE","$3M","$2.6M","+52.6%"],
    ["2025-06-20","N/A","other","SELL","$32.5K","-","-"],
    ["2025-01-14","AMZN","options","BUY","$375K","$38.3K","+7.7%"],
    ["2025-01-14","GOOGL","options","BUY","$375K","$332.6K","+66.5%"],
    ["2025-01-14","NVDA","options","BUY","$375K","$188.6K","+37.7%"],
    ["2025-01-14","TEM","options","BUY","$75K","$132.4K","+132.4%"],
    ["2025-01-14","VST","options","BUY","$750K","$12K","+1.2%"],
    ["2024-12-31","AAPL","stock","SELL","$15M","$3.6M","+14.3%"],
    ["2024-12-31","NVDA","stock","SELL","$3M","$1.8M","+35.1%"],
    ["2024-12-31","AAPL","stock","SELL","$10M","$2.1M","+14.3%"],
    ["2024-12-20","NVDA","stock","BUY","$750K","$347.1K","+34.7%"],
    ["2024-12-20","PANW","stock","BUY","$3M","$83K","+1.7%"],
    ["2024-08-13","N/A","stock","BUY","$375K","-","-"],
    ["2024-07-26","MSFT","stock","SELL","$3M","$761K","+15.2%"],
    ["2024-07-26","NVDA","stock","BUY","$3M","$3M","+60.5%"],
    ["2024-07-01","V","stock","SELL","$750K","$252.2K","+25.2%"],
    ["2024-06-26","NVDA","stock","BUY","$3M","$2.2M","+43.6%"],
    ["2024-06-24","AVGO","options","BUY","$3M","$7M","+139.6%"],
    ["2024-06-24","TSLA","stock","SELL","$375K","$675.5K","+135.1%"],
    ["2024-03-04","N/A","other-investment-fund","BUY","$3M","-","-"],
    ["2024-02-21","PANW","options","BUY","$175K","$112.4K","+45.0%"],
    ["2024-02-12","PANW","options","BUY","$750K","$20.9K","+2.1%"],
    ["2023-11-22","NVDA","options","BUY","$3M","$13.6M","+272.5%"],
    ["2023-11-22","N/A","options","BUY","$3M","-","-"],
    ["2023-06-15","AAPL","options","BUY","$375K","$269.3K","+53.9%"],
    ["2023-06-15","MSFT","options","BUY","$750K","$407.6K","+40.8%"],
    ["2023-05-08","AAPL","stock","EXCHANGE","$750K","$0","0.0%"],
    ["2023-03-17","AAPL","options","BUY","$750K","$846.4K","+84.6%"],
    ["2023-03-09","None","stock","BUY","$750K","-","-"],
    ["2023-03-09","N/A","stock","BUY","$750K","-","-"],
    ["2023-01-20","RBLX","options","SELL","$8K","$24.7K","+164.8%"],
    ["2023-01-20","N/A","options","SELL","$8K","-","-"],
    ["2022-12-30","NFLX","stock","SELL","$375K","$1.4M","+270.8%"],
    ["2022-12-29","NFLX","stock","SELL","$375K","$1.4M","+275.6%"],
    ["2022-12-28","AB","stock","SELL","$750K","$258.4K","+25.8%"],
    ["2022-12-28","GOOGL","stock","SELL","$750K","$2.7M","+267.1%"],
    ["2022-12-28","PYPL","stock","SELL","$375K","-$34.4K","-6.9%"],
    ["2022-12-28","RBLX","stock","SELL","$175K","$645.5K","+258.2%"],
    ["2022-12-28","C","stock","SELL","$750K","$1.3M","+131.3%"],
    ["2022-12-21","DIS","stock","SELL","$750K","$206.1K","+20.6%"],
    ["2022-12-21","GOOGL","stock","SELL","$750K","$2.5M","+252.5%"],
    ["2022-12-21","PYPL","stock","SELL","$375K","-$45.6K","-9.1%"],
    ["2022-12-20","CRM","options","SELL","$8K","$12.4K","+82.7%"],
    ["2022-12-20","GOOGL","stock","SELL","$750K","$2.5M","+254.8%"],
    ["2022-12-20","TSLA","stock","SELL","$750K","$2.1M","+211.5%"],
    ["2022-12-20","CRM","options","SELL","$9","$7.4","+82.7%"],
    ["2022-11-08","V","stock","SELL","$3M","$3.2M","+63.4%"],
    ["2022-09-16","DIS","options","SELL","$8K","-$473.9","-3.2%"],
    ["2022-09-16","GOOGL","stock","BUY","$3M","$10.4M","+207.2%"],
    ["2022-09-16","MU","options","SELL","$32.5K","$176.6K","+353.2%"],
    ["2022-09-16","NVDA","options","SELL","$175K","$3.2M","+1274.7%"],
    ["2022-09-16","DIS","options","SELL","$1","-$0","-3.2%"],
    ["2022-09-16","GOOG","options","BUY","$3M","$10.2M","+205.0%"],
    ["2022-08-24","None","stock","BUY","$32.5K","-","-"],
    ["2022-08-24","N/A","other","BUY","$32.5K","-","-"],
    ["2022-07-26","NVDA","stock","SELL","$3M","$49.9M","+997.8%"],
    ["2022-06-21","V","stock","SELL","$3M","$3.5M","+69.6%"],
    ["2022-06-17","AAPL","options","SELL","$175K","$293.8K","+117.5%"],
    ["2022-06-17","NVDA","stock","BUY","$3M","$52.1M","+1042.7%"],
    ["2022-05-24","AAPL","options","BUY","$375K","$519.5K","+103.9%"],
    ["2022-05-24","MSFT","options","BUY","$75K","$88.7K","+88.7%"],
    ["2022-05-24","MSFT","options","BUY","$375K","$443.7K","+88.7%"],
    ["2022-05-13","AAPL","options","BUY","$750K","$945.4K","+94.5%"],
    ["2022-04-11","T","stock","EXCHANGE","$75K","$0","0.0%"],
    ["2022-04-11","WBD","stock","BUY","$75K","-$1K","-1.0%"],
    ["2022-03-17","TSLA","stock","BUY","$3M","$2.4M","+47.7%"],
    ["2022-01-27","AB","stock","BUY","$375K","-$48.9K","-9.8%"],
    ["2022-01-21","AAPL","options","BUY","$3M","$3.8M","+76.2%"],
    ["2022-01-21","AAPL","stock","BUY","$750K","$762.1K","+76.2%"],
    ["2022-01-21","AXP","stock","BUY","$375K","$636.1K","+127.2%"],
    ["2022-01-21","DIS","options","BUY","$3M","-$1.2M","-23.7%"],
    ["2022-01-21","DIS","stock","BUY","$750K","-$236.9K","-23.7%"],
    ["2022-01-21","PYPL","options","BUY","$750K","-$615.4K","-61.5%"],
    ["2022-01-21","PYPL","stock","BUY","$375K","-$307.7K","-61.5%"],
    ["2021-12-30","AAPL","stock","EXCHANGE","$750K","$0","0.0%"],
    ["2021-12-22","None","stock","BUY","$75K","-","-"],
    ["2021-12-22","ONE","other","BUY","$75K","$387.4K","+387.4%"],
    ["2021-12-21","MU","options","BUY","$375K","$820.5K","+164.1%"],
    ["2020-05-08","V","stock","SELL","$750K","$780.9K","+78.1%"],
    ["2020-05-08","FB","stock","SELL","$3M","$0","0.0%"],
    ["2020-04-28","None","stock","BUY","$32.5K","-","-"],
    ["2020-02-28","MSFT","options","BUY","$175K","$506.1K","+202.5%"],
    ["2020-02-27","GOOGL","options","BUY","$750K","$3.8M","+380.3%"],
    ["2020-02-21","MSFT","options","BUY","$750K","$1.7M","+174.4%"],
    ["2020-02-20","MSFT","options","BUY","$375K","$828.5K","+165.7%"],
    ["2020-02-20","WORK","stock","BUY","$375K","$322.1K","+64.4%"],
    ["2020-01-21","None","stock","BUY","$75K","-","-"],
    ["2020-01-16","AMZN","options","SELL","$250K","$374.1K","+149.6%"],
    ["2020-01-16","AMZN","options","SELL","$375K","$748.2K","+149.6%"],
    ["2020-01-16","AMZN","stock","BUY","$3M","$7.5M","+149.6%"],
    ["2020-01-16","META","stock","BUY","$375K","$958.9K","+191.8%"],
    ["2020-01-16","FB","stock","BUY","$375K","$0","0.0%"],
    ["2019-08-07","V","stock","SELL","$175K","$220K","+88.0%"],
    ["2019-07-22","AMZN","stock","BUY","$750K","$1.4M","+136.1%"],
    ["2019-07-22","NFLX","stock","BUY","$175K","$630.2K","+252.1%"],
    ["2016-01-13","AAPL","stock","BUY","$375K","$5.4M","+1075.3%"],
    ["2015-12-30","CRM","stock","SELL","$75K","$196.6K","+196.6%"],
    ["2015-12-30","V","stock","SELL","$175K","$801.8K","+320.7%"],
    ["2015-12-29","V","stock","SELL","$375K","$1.6M","+316.1%"],
    ["2015-07-16","HTZ","stock","BUY","$175K","-$202.5K","-81.0%"],
    ["2015-07-15","HTZ","stock","BUY","$32.5K","-$40.5K","-81.0%"],
    ["2014-12-30","V","stock","SELL","$175K","$995.9K","+398.4%"],
    ["2014-12-29","V","stock","SELL","$375K","$2M","+396.7%"],
    ["2014-12-10","DIS","stock","BUY","$75K","$14.4K","+14.4%"],
    ["2014-11-28","DIS","stock","BUY","$8K","$2K","+13.3%"],
    ["2014-11-28","HTZ","stock","BUY","$75K","-$81K","-81.0%"],
    ["2014-11-25","HTZ","stock","BUY","$175K","-$202.5K","-81.0%"]
]

df = pd.DataFrame(data, columns=["date","ticker","category","action","amount","proceeds","return"])
df
# Out:
#            date ticker category    action  amount  proceeds   return
# 0    2025-06-20   AVGO    stock  EXERCISE     $3M     $2.6M   +52.6%
# 1    2025-06-20    N/A    other      SELL  $32.5K         -        -
# 2    2025-01-14   AMZN  options       BUY   $375K    $38.3K    +7.7%
# 3    2025-01-14  GOOGL  options       BUY   $375K   $332.6K   +66.5%
# 4    2025-01-14   NVDA  options       BUY   $375K   $188.6K   +37.7%
# ..          ...    ...      ...       ...     ...       ...      ...
# 179  2014-12-29      V    stock      SELL   $375K       $2M  +396.7%
# 180  2014-12-10    DIS    stock       BUY    $75K    $14.4K   +14.4%
# 181  2014-11-28    DIS    stock       BUY     $8K       $2K   +13.3%
# 182  2014-11-28    HTZ    stock       BUY    $75K     -$81K   -81.0%
# 183  2014-11-25    HTZ    stock       BUY   $175K  -$202.5K   -81.0%
#
# [184 rows x 7 columns]

# %% [markdown]
# ### Compute the total amount of money traded and the use it as weights

# %%
def money_to_number(x):
    if x in ["-", None, ""]:
        return 0
    x = x.replace("$", "")
    if "M" in x:
        return float(x.replace("M", "")) * 1_000_000
    if "K" in x:
        return float(x.replace("K", "")) * 1_000
    return float(x)
    
df["amount_num"] = df["amount"].apply(money_to_number)"

df['weights'] = df['amount_num'] / df['amount_num'].sum()

df
# Out:
#            date ticker category    action  amount  proceeds   return  \
# 0    2025-06-20   AVGO    stock  EXERCISE     $3M     $2.6M   +52.6%
# 1    2025-06-20    N/A    other      SELL  $32.5K         -        -
# 2    2025-01-14   AMZN  options       BUY   $375K    $38.3K    +7.7%
# 3    2025-01-14  GOOGL  options       BUY   $375K   $332.6K   +66.5%
# 4    2025-01-14   NVDA  options       BUY   $375K   $188.6K   +37.7%
# ..          ...    ...      ...       ...     ...       ...      ...
# 179  2014-12-29      V    stock      SELL   $375K       $2M  +396.7%
# 180  2014-12-10    DIS    stock       BUY    $75K    $14.4K   +14.4%
# 181  2014-11-28    DIS    stock       BUY     $8K       $2K   +13.3%
# 182  2014-11-28    HTZ    stock       BUY    $75K     -$81K   -81.0%
# 183  2014-11-25    HTZ    stock       BUY   $175K  -$202.5K   -81.0%
#
#      amount_num   weights
# 0     3000000.0  0.016115
# 1       32500.0  0.000175
# 2      375000.0  0.002014
# 3      375000.0  0.002014
# ...

# %%
# ta bort aktier med "N/A" / "None" ticker
valid_tickers = df[~df["ticker"].isin(["N/A", "None"])]["ticker"].unique().tolist()
df = df[df["ticker"].isin(valid_tickers)]

# YFINANCE data nerladdnign
start_download = pd.to_datetime(df["date"].min())
end_download = pd.to_datetime("2025-01-01")

# ladda ner data på aktier som har handlats
market_data = yf.download(valid_tickers, start=start_download, end=end_download)["Open"]

# fyll luckor under helgen med fredags pris
market_data = market_data.ffill()



@dataclass
class Position:
    shares: float
    entry_price: float
    direction: str
    entry_date: str




@dataclass
class Portfolio:
    positions: dict = field(default_factory=dict)
    history: list = field(default_factory=list)



    def add_position(self, ticker: str, price: float, direction: str, date: str):
        if pd.isna(price):
            print(f"Skipping {ticker} on {date} (No Price Data)")
            return

        notional = 100.0  # $100 per signal
        shares = notional / price

        if direction.upper() == "SELL":
            shares = -shares  # kort position

        pos = Position(shares, price, direction.upper(), date)

        if ticker not in self.positions:
            self.positions[ticker] = []
        self.positions[ticker].append(pos)



    def value_on_date(self, date_ts):
        total_value = 0

        if date_ts not in market_data.index:
            return 0

        for ticker, lots in self.positions.items():
            if ticker not in market_data.columns:
                continue

            price = market_data.loc[date_ts, ticker]

            if pd.isna(price):
                continue


            for lot in lots:
                total_value += lot.shares * price


        return total_value



    def record_daily(self, date_ts):
        value = self.value_on_date(date_ts)
        self.history.append({"date": date_ts, "value": value})



    def get_history_df(self):
        return pd.DataFrame(self.history)



# skapa en portfölj
portfolio = Portfolio()
daily_capital_additions = []

# sortera signal i order av datum
df["date"] = pd.to_datetime(df["date"])
df = df.sort_values("date")

start_date = df["date"].min()
end_date = df["date"].max()
simulation_dates = pd.date_range(start=start_date, end=end_date)

for current_date in simulation_dates:
    string_date = current_date.strftime("%Y-%m-%d")

    # 1. updatera portfölj värde M2M (mark-to-market)
    portfolio.record_daily(current_date)

    # 2. kolla efter ny signal idag
    todays_signals = df[df["date"] == current_date]

    if todays_signals.empty:
        continue

    for _, row in todays_signals.iterrows():
        ticker = row["ticker"]
        direction = row["action"]

        # kolla pris och lägg till position i portfölj
        if current_date in market_data.index and ticker in market_data.columns:
            price = market_data.loc[current_date, ticker]
            portfolio.add_position(ticker, price, direction, string_date)

            # lång == ta bort cash, kort == få cash
            capital_added_today = 100 * len(todays_signals) * (-1 if direction.upper() == "SELL" else 1)

            daily_capital_additions.append({"date": current_date, "capital_added": capital_added_today})
# Out:
# /tmp/ipykernel_259261/4102968533.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   market_data = yf.download(valid_tickers, start=start_download, end=end_download)["Open"]
# [*********************100%***********************]  34 of 34 completed
#
# 4 Failed downloads:
# ['WORK', 'SQ', 'ONE']: YFTzMissingError('possibly delisted; no timezone found')
# ['FB']: YFPricesMissingError('possibly delisted; no price data found  (1d 2014-11-25 00:00:00 -> 2025-01-01 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1416891600, endDate = 1735707600")')
# Skipping HTZ on 2014-11-25 (No Price Data)
# Skipping HTZ on 2014-11-28 (No Price Data)
# Skipping HTZ on 2015-07-15 (No Price Data)
# Skipping HTZ on 2015-07-16 (No Price Data)
# Skipping SQ on 2016-05-17 (No Price Data)
# Skipping SQ on 2017-01-20 (No Price Data)
# Skipping FB on 2018-07-27 (No Price Data)
# Skipping FB on 2018-10-09 (No Price Data)
# ...

# %%
history_df = portfolio.get_history_df()
history_df.set_index("date", inplace=True)

plt.figure(figsize=(12, 6))
plt.plot(history_df.index, history_df["value"], label="Portfolio Value")
plt.title("Portfolio Value")
plt.xlabel('Date')
plt.ylabel("Value ($)")
plt.grid(True)
plt.legend()
plt.show()

# %%
history_df = portfolio.get_history_df()
history_df.set_index("date", inplace=True)

# vårt "initial capital"
capital_df = pd.DataFrame(daily_capital_additions)
capital_df.set_index("date", inplace=True)

final_df = history_df.merge(capital_df, left_index=True, right_index=True, how="outer")
final_df["cumulative_capital"] = final_df["capital_added"].cumsum()

# gör grafen kontinuerlig
final_df["cumulative_capital"] = final_df["cumulative_capital"].ffill()
final_df["cumulative_capital"] = final_df["cumulative_capital"].fillna(0)



# Now plot the two lines
plt.figure(figsize=(12, 6))
plt.plot(final_df.index, final_df["value"], label="Portfolio Value (P&L)")
plt.plot(final_df.index, final_df["cumulative_capital"], label="Cumulative Capital/Credit", color="red")
plt.title("Portfolio Value vs. Cumulative Capital/Credit")
plt.xlabel("Date")
plt.ylabel("Value (USD)")
plt.grid(True)
plt.legend(loc="upper left")
plt.show()
